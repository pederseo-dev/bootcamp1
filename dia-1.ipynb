# %% [markdown]
# ## Qué es un lenguaje de programación
#
# Un lenguaje de programación es una forma de comunicarnos con una computadora e indicarle una serie de instrucciones de lo que queremos hacer.

# %% [markdown]
# ## Qué es Python
#
# Es un lenguaje de programación de sintaxis sencilla, amigable y trata de parecerse en lo mayor posible al lenguaje humano.
# Como está escrito en inglés, es más parecido a ese idioma.

# %%
print('hola mundo')
# Out:
# hola

# %% [markdown]
# ## Definición de variables
#
# Las variables son espacios en memoria de la computadora en los cuales podemos guardar datos durante la ejecución de nuestro programa.
#
# A estos espacios les podemos poner nombres por medio de los cuales podemos acceder más tarde a los valores que contienen.

# %% [markdown]
# `✏️ ¿Cómo nombrar una variable?`
#
# Algunas reglas y buenas prácticas para nombrar variables en Python:
#
# - ✅ Puede incluir letras, números y guiones bajos (_).
# - ✅ Debe empezar con una letra o guión bajo, nunca con un número.
# - ✅ Evitar usar palabras reservadas de Python (como print, def, if, etc).
# - ✅ Usar nombres descriptivos (¡no pongas x, a, b si no hace falta!).

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# El Zen de Python, por Tim Peters
#
# - `Lo bello es mejor que lo feo. `- El código debe ser elegante y estéticamente agradable, no solo funcional. Un código "bello" es claro, intuitivo y fácil de entender, lo que facilita su mantenimiento y colaboración.
# - `Explícito es mejor que implícito. ` Si un problema requiere una solución compleja, está bien, siempre que no sea "complicada" (es decir, confusa o enredada).
# - `Simple es mejor que complejo.` Si hay una forma sencilla de resolver un problema, úsala. La simplicidad reduce errores y facilita el mantenimiento.
# - `Complejo es mejor que complicado.` Si un problema requiere una solución compleja, está bien, siempre que no sea "complicada" (es decir, confusa o enredada).
# - `Plano es mejor que anidado.` Evita anidar estructuras (como bucles o condicionales) en exceso, ya que esto dificulta la lectura y el mantenimiento del código.
# - `Espaciado es mejor que denso.` El uso adecuado de espacios en blanco (saltos de línea, indentación, espacios entre operadores) mejora la legibilidad del código.
# - `La legibilidad cuenta.` El código debe ser fácil de leer y entender, tanto para el autor como para otros desarrolladores.
# - `Los casos especiales no son tan especiales como para romper las reglas.` No hagas excepciones a las convenciones de Python solo porque un caso parece especial. Mantener la consistencia en el estilo y las prácticas es más importante.
# - `Aunque lo práctico gana a lo puro.` Aunque seguir las reglas es ideal, a veces es necesario priorizar soluciones prácticas que resuelvan el problema, incluso si no son perfectamente "puras" o académicas.
# - `Los errores nunca deberían pasar en silencio.`Los errores deben ser detectados y manejados explícitamente para evitar problemas ocultos.
# - `A menos que se silencien explícitamente.` Si decides ignorar un error, hazlo de manera intencional y explícita usando un bloque try-except, documentando por qué lo haces.
# - `Ante la ambigüedad, rechaza la tentación de adivinar.` Si el código o los datos son ambiguos, no intentes adivinar lo que el usuario quiso decir. Pide claridad o valida los datos.
# - `Debe haber una —y preferiblemente solo una— manera obvia de hacerlo.` Python busca que las soluciones sean claras y consistentes, con una forma preferida de resolver un problema, reduciendo la confusión.
# - `Aunque esa manera puede no ser obvia al principio a menos que seas holandés.` Una broma sobre Guido van Rossum, creador de Python, quien es holandés. Algunas soluciones pueden no ser evidentes para principiantes, pero con experiencia se vuelven claras.
# - `Ahora es mejor que nunca.` Es mejor escribir código funcional ahora que esperar a una solución perfecta que nunca llega.
# - `Aunque nunca es a menudo mejor que ahora mismo.` A veces, no hacer algo (o no apresurarse) es mejor que implementar una solución apresurada y defectuosa.
# - `Si la implementación es difícil de explicar, es una mala idea.` Si no puedes explicar fácilmente cómo funciona tu código, probablemente sea demasiado complicado o confuso.
# - `Si la implementación es fácil de explicar, puede ser una buena idea.` Si puedes describir tu código de manera simple, es probable que sea una buena  solución. La claridad es un indicador de calidad.
# - `¡Los espacios de nombres son una gran idea — hagamos más de esos!` Los espacios de nombres (como módulos, clases, o funciones) ayudan a organizar el código y evitar conflictos entre variables o funciones.

# %%
# vairables
cantidad_frutas = 4

print(cantidad_frutas)
# Out:
# manzana

# %%
# tipos de datos

edad = 28 #-> int
altura = 1.80 #-> float
nombre = 'olaf' # -> str
feliz = True #-> bool

print(edad)
print(altura)
print(nombre)
print(feliz)
# Out:
# 28
# 1.8
# olaf
# True

# %% [markdown]
# ## Qué es un challenge
# Un "challenge"  es una tarea o problema que se plantea para poner a prueba las habilidades y el conocimiento de alguien. En el contexto de la programación , los challenges son actividades o ejercicios diseñados para desafiar a los participantes y motivarlos a aplicar sus nuevos conocimientos y habilidades adquiridas.

# %% [markdown]
# ## Challenge 🤺
# Crea 3 variables con tu nombre, edad y ciudad. Imprime en una sola línea usando `print()`

# %% [markdown]
# ### Operadores aritméticos
# - `+` - Suma
# - `-` - Resta
# - `*` - Multiplicación
# - `/` - División
# - `//` - División entera (sin decimales)
# - `%` - Resto (módulo)

# %%
producto1 = "lomito"
costo_producto1 = 25000

producto2 = 'coca cola'
costoproducto2 = 5000

capital = 50000
dolar = 6650

#ejemplo suma
costo_total = costo_producto1 + costoproducto2
print('el costo total es: ', costo_total)

# ejemplo resta
vuelto = capital - costo_total
print('el vuelto es', vuelto)

# ejemplo division
vuelto_en_dolares = vuelto/dolar
print('mi vuelto en dolares es: ', vuelto_en_dolares)
# Out:
# el costo total es:  30000
# el vuelto es 20000
# mi vuelto en dolares es:  3.007518796992481

# %% [markdown]
# ## Challenge 🤺 - 20m
#
# Suma: asignar dos números en dos variables diferentes `cantidad_de_manzanas` y `cantidad_de_naranjas`. Luego sumar ambas variables en `cantidad_de_frutas`. Imprimir la última variable.
#
# Resta: asignar un valor numérico a la variable `frutas_vendidas`. Luego, asignar la resta entre `cantidad_de_frutas` y `frutas_vendidas` a la variable `frutas_restantes`. Imprimir la última variable.

# %%
#Valor de cada variable
cantidadDeManzanas = 19203
cantidadDeNaranjas = 18230
frutasVendidas = 10000
#Calculo solicitado
cantidadDeFrutas = cantidadDeNaranjas + cantidadDeManzanas
frutasRestantes = cantidadDeFrutas - frutasVendidas
print(f"La cantidad de frutas restantes es: {frutasRestantes}")
# Out:
# La cantidad de frutas restantes es: 27433

# %%
#Ejemplo operaciones
cantidad_de_naranjas = 10
cantidad_de_manzanas = 7
cantidad_de_frutas = cantidad_de_naranjas + cantidad_de_manzanas
print('El total de las frutas es de: ', cantidad_de_frutas)

frutas_vendidas = 12
frutas_restantes = cantidad_de_frutas - frutas_vendidas
print('La cantidad de frutas restantes es: ', frutas_restantes)
# Out:
# El total de las frutas es de:  17
# La cantidad de frutas restantes es:  5

# %% [markdown]
# # concatenacion

# %%
nombre = 'claudia'
apellido = 'melgarejo'

# valores diferentes
print(nombre, apellido)

# concatenacion
print(nombre + " " + apellido)

# insertar variables dentro de un string
print(f'hola mi nombre es {nombre} {apellido}')

# %% [markdown]
# ## Challenge 🤺 - 15m
#
# Asignar el nombre y el apellido de tu compañera/o a las variables `nombre` y `apellido`. Luego, `imprimir` una frase, utilizando las variables.
# EJEMPLO: "Hola. Me llamo Claudia Melgarejo. Mucho gusto."

# %%
#ejerciccios de concatenacion 


#Challenge 🤺 - 15m
#Asignar el nombre y el apellido de tu compañera/o a las variables nombre y apellido. Luego, imprimir una frase, utilizando las variables.
#EJEMPLO: "Hola. Me llamo Claudia Melgarejo. Mucho gusto."



nombre ='Pablo'
apellido=  'Bogarin'
nombre_completo= nombre + " "+apellido


print(f'Hola me llamo {nombre_completo}. ! Mucho Gusto ! :)')
# Out:
# Hola me llamo Pablo Bogarin. ! Mucho Gusto ! :)

# %%
nombre = ("Fio")
apellido = ("Mercado")
#concatenacion
print (f"ella es mi compañera {nombre} {apellido}")
# Out:
# ella es mi compañera Fio Mercado

# %%
# ejemplo 1
# dato = input()
# print(type(dato))

# ejemplo 2
# un_producto = input('Que producto desea?')
# print(un_producto)

# print(f' Quisiera comprar un {un_producto}')


edad = 19
print(type(edad))

edad = "19"
print(type(edad))

edad = 19.0
print(type(edad))

edad = True
print(type(edad))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>

# %%
cantidad_de_manzanas = int(input('ingrese catidad de manzanas'))
cantidad_de_naranjas = int(input('ingrese catidad de naranjas'))
cantidad_total = cantidad_de_naranjas + cantidad_de_manzanas
print(cantidad_total)
# Out:
# 76

# %% [markdown]
# Challenge 🤺 – 10m
#
# 🎯 Objetivo: Practicar división y módulo.
#
# Imagina que estás repartiendo caramelos: solicita al usuario ingresar el total de caramelos y la cantidad de niños, luego calcula cuántos caramelos recibe cada niño usando división entera y cuántos sobran usando módulo, e imprime ambos resultados.

# %% [markdown]
# ### Operadores aritméticos
# - `+` - Suma
# - `-` - Resta
# - `*` - Multiplicación
# - `/` - División
# - `//` - División entera (sin decimales)
# - `%` - Resto (módulo)

# %%
caramelos=int(input("Ingrese cantidad de caramelos totales"))
ninos=int(input("Ingrese cantidad de niños"))
caramelos_por_nino= caramelos//ninos
sobrante= caramelos%ninos
print("son ",caramelos_por_nino," caramelos por niño y sobran ",sobrante,"caramelos")
# Out:
# son  2  caramelos por niño y sobran  0 caramelos

# %%
total_caramelos = int(input("¿Cuál es tu cantidad de caramelos?:"))
niños = int(input("¿Cuántos niños hay?: "))
caramelos_por_niño = total_caramelos // niños

print(caramelos_por_niño)
caramelos_sobrantes = total_caramelos - caramelos_por_niño
print(caramelos_sobrantes)
# Out:
# 2
# 9

# %% [markdown]
# ## Qué es un algoritmo
# Un algoritmo es una serie de pasos o instrucciones definidos y ordenados para resolver un problema o completar una tarea específica, muy de la mano de lo que es el pensamiento computacional. Los algoritmos se utilizan para describir cómo se deben llevar a cabo procesos de manera precisa y detallada, debe tener un número finito de pasos y terminar en algún momento.

# %% [markdown]
# ## Definición
#
# Las funciones son un conjunto de instrucciones de una operacion que quisieramos volver a repetir en diferentes partes de nuestro programa.
#
# Las funciones existen para permitirnos re utilizar codigo que ya escribimos anteriormente, sin la necesidad de volver a escribirlo.
#
# Imaginá que estás preparando un sándwich. Siempre seguís los mismos pasos, entonces en vez de escribir esas instrucciones cada vez, podés agruparlas en una función y simplemente "llamarla" cuando lo necesites.

# %%
def saludo_general():
    nombre = input('ingrese su nombre ')
    apellido2 = input('ingrese su edad ')
    print(f'hola mi nombre es {nombre} {apellido2}')

saludo_general()
saludo_general()

# %% [markdown]
# ## Challenge 🤺 - 15m
#
# `Crear` una función de un proceso que se les ocurra que tenga `varios` pasos.
#
# - Ejecutar la función 3 veces.

# %%
def alimentacion_michi():
    nombre_gato = input("Ingrese el nombre de su gato: ")
    cant_whiskas = int(input("Ingrese la cantidad de whiskas que ingiere por dia: "))
    peso_gatuno = (input("Ingrese el peso de su gato en kg: "))
    print(f"El nombre de su gato es: {nombre_gato}. E ingiere {cant_whiskas} whiskas por dia, pesa {peso_gatuno} kg.")

alimentacion_michi()
# Out:
# El nombre de su gato es: miauricio. E ingiere 20 whiskas por dia, pesa 100 kg.
# El nombre de su gato es: ramon. E ingiere 8 whiskas por dia, pesa 800 kg.

# %%
def gastos():

    nombre_gasto1 = input("Ingrese en que fue su primer gasto")
    valor_gasto1 = int(input("Ingrese el monto de su primer gasto"))

    nombre_gasto2 = input("Ingrese en que fue su primer gasto")
    valor_gasto2 = int(input("Ingrese el monto de su segundo gasto"))

    nombre_gasto3 = input("Ingrese en que fue su tercer gasto")
    valor_gasto3 = int(input("Ingrese el monto de su tercer gasto"))
    print(f"{nombre_gasto1}, {nombre_gasto2} y {nombre_gasto3} fue en lo que gasto")

    valor_total_gastado = valor_gasto1 + valor_gasto2 + valor_gasto3
    print(f"Este es el monto total que gasto {valor_total_gastado}")

gastos()
gastos()
gastos()
# Out:
# pasaje, camida y marianda fue en lo que gasto
# Este es el monto total que gasto 48400

# %%
combo_usuario = input('ingrese su pedido ')
bebida = input('ingrese su agregado ')

def preparar_pedido(combo, agregado): # parametrso
    print(f'preparando tu combo: {combo} con agregado {agregado}')
    print('pedido listo 🍔')


preparar_pedido(combo_usuario, bebida) # argumentos
# Out:
# preparando tu combo: big mac con agregado coca cola
# pedido listo 🍔

# %% [markdown]
# Challenge 🤺 - 25m
#
# Escribir una funcion que represente un sistema de pedidos de comida rapida.
#
# La funcion debe recibir como parametros el nombre del producto y el tamaño del pedido.
#
# Al ejecutarse, debe imprimir en pantalla el detalle del pedido de forma clara y ordenada.
#
# Luego, llamar a la funcion pasando los argumentos correspondientes para simular que un cliente realiza un pedido.

# %%
pedido_auto = input('Que modelo le interesa')
version_auto = input('en que version le interesa. Simple, Equipada, Full')
def pedido(modelo, version):
    print(f'preparando tu {modelo}, sera entregado en las proximas horas')
    print(f'su {modelo} estara listo en cuanto lleguen las versiones {version}')

pedido(pedido_auto, version_auto)
# Out:
# preparando tu fuzca, sera entregado en las proximas horas
# su fuzca estara listo en cuanto lleguen las versiones 1992

# %%
cafe_usuario = input('Que café va a querer?')
tamaño_usuario = input('De que medida quisiera su café? (pequeño, mediano, grande)')
agregado_azucar = input('Lo quisiera "con azúcar" o "sin azúcar"?')

def preparar_cafe(cafe, tamaño, azucar):
    print(f'Ya estamos preparando su café {cafe} de tamaño {tamaño} {azucar}')
    print('Su café esta listo, puede retirarlo :)')


preparar_cafe(cafe_usuario, tamaño_usuario, agregado_azucar)
# Out:
# Ya estamos preparando su café latte de tamaño grande con 5 de azucar
# Su café esta listo, puede retirarlo :)

# %%
def pedidos(a,b):
    print('! Su pedido esta listo !')
    print(f'Su pedido es : {a} cantidad  {b}')
    
pedidos(input('ingrese su orden '),int(input('cuntos va querer ? ')))
# Out:
# ! Su pedido esta listo !
# Su pedido es : mondongo cantidad  -1

# %%
# funcion personalizada
preparar_pedido('big mac')

# Funciones predeterminadas de python
print('mnesaje')
input()

# %% [markdown]
# ## Alcance (Scope)
#
# Cuando usamos variables en Python, tenemos que entender dónde viven esas variables, es decir, su alcance o scope.
#
# Hay dos tipos principales:
#
# 🔸 Alcance local: la variable vive dentro de una función y solo se puede usar ahí.
#
# 🔹 Alcance global: la variable vive fuera de todas las funciones y se puede usar en todo el programa.
#
# Qué pasa si con una función, queremos modificar una variable que declaramos más arriba?

# %%
ingrediente = 'jamon'

def preparar_sandwich():


    ingrediente = 'queso'
    print(ingrediente)
    

preparar_sandwich()  



# print(ingrediente)

# %% [markdown]
# Challenge 🤺 - 10m
#
# 🎯 Objetivo:
# Practicar variables globales y locales.
#
# Escribir una función calcular_total que reciba el precio de un producto y calcule el total sumando un impuesto global impuesto = 10.
# Usa una variable local total para almacenar el resultado e imprime el total.
# Llama a la función con distintos precios para probar.

# %%
#variable
calcular_total=int(input("Ingrese el valor del producto"))
impuesto=10
#Funcion
def total(precio):#fun_impuesto, parametro para el impuesto global
    calcular_impuesto = precio + impuesto
    print(f"El total es: {calcular_impuesto}")
#llamado de funcion
total(calcular_total)
# Out:
# El total es: 20010

# %%
impuesto = 0.1 # porcentaje de impuesto

def calcular_total(precio, cantidad):
    total = precio * cantidad
    total_mas_iVA = total + (total * impuesto)

    print  (f"El total a pagar por {cantidad} productos es: {total_mas_iVA} Guaranies")

calcular_total(int(input("Ingrese el precio del producto: ")), int(input("Ingrese la cantidad de productos: ")))
# Out:
# El total a pagar por 5 productos es: 275000.0 Guaranies
