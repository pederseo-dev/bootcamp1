# %%
def imprimir_saludo():
    print('hola mundo')
    
imprimir_saludo()
# Out:
# hola mundo

# %% [markdown]
# ## Challenge 1 🤺 - 15m
#
# Crear una función que imprima la variable palabra.

# %%
def imprimir_palabra():
    palabra = 'hola'
    print(palabra)

imprimir_palabra()
# Out:
# hola

# %%
def sumar_numeros(numero1, numero2):
    sumar = numero1 + numero2
    print(sumar)

sumar_numeros(500, 300)
sumar_numeros(700, 800)
# Out:
# 800
# 1500

# %% [markdown]
# ## Challenge 2 🤺 - 15 min
# Crear una función que `reciba` dos letras `(parámetros)` y que `verifique` si son iguales:
#
# 1. `Si son iguales`, imprimir "Las letras son iguales".
#
# 2. `De lo contrario`, imprimir "Las letras son diferentes".

# %%
def comparar_letras(letra1, letra2): # a, b
    if letra1 == letra2:
        print("Las letras son iguales")
    
    else:
        print("Las letras son diferentes")



comparar_letras('a', 'a')
# Out:
# Las letras son iguales

# %% [markdown]
# # Funciones con return

# %%
# ejemplo 1
def sumar():
    operacion_suma = 2 + 2
    return operacion_suma

resultado = sumar()
print(resultado)
# Out:
# 0

# %%
def cajero(cantidad):
    fondos = 100000
    if fondos >= cantidad:
        print(f'el estracto de retiro: {cantidad}')
        fondos = fondos - cantidad
        return cantidad


    else:
        print(f'fondos insuficientes')
        return 0

extraccion_de_dinero = cajero(110000)
print(f'la cantidad extraida es de: {extraccion_de_dinero}')
# Out:
# fondos insuficientes
# la cantidad extraida es de: 0

# %%
def verificar_palabras(palabra_a_ancontrar, palabra_ingresada):
    palabras_son_iguales = palabra_a_ancontrar == palabra_ingresada

    if palabras_son_iguales:
        return 'Las palabras son iguales'
    
    else:
        return ' las palabras son diferentes'
    

palabra_usuario = input('ingrese la palabra a adivinar')
palabra_secreta = 'gato'

resultado = verificar_palabras(palabra_secreta, palabra_usuario)
print(resultado)
# Out:
# Las palabras son iguales

# %% [markdown]
# ## Challenge 3 🤺 - 20m
#
# Crear una función que reciba `dos parámetros` (una palabra y un número), y que retorne `True` si el `número es igual` a la cantidad de letras de la palabra. En caso contrario, que retorne `False`.
#
# Imprimir resultado de la funcion.
#
# Pista: `cantidad de letras de una palabra en python`

# %%
#solucion de rodrigo
palabra_usuario = input('Ingrese una palabra')
numero_usuario = int(input('Ingrese un numero'))

def cantidad_letras(word, number):

    numero_de_letras = len(word)

    if numero_de_letras == number:
        return True

    else:
        return False

resultado = cantidad_letras(palabra_usuario, numero_usuario)
print (resultado)
# Out:
# True

# %%
# solucion de cristhian
def verificar_palabra (palabra , número):
    if len (palabra) == número:
        return True
    else:
        return False
verificar_palabra ('python', 6)
# Out:
# True

# %%
palabra_a_encontrar = input('ingrese una palabra')
print(palabra_a_encontrar)

palabra_ingresada = input(' ingrese otra palabra')
print(palabra_ingresada)

lista_de_lestras_de_la_palabra_a_encontrar = list(palabra_a_encontrar)
print(lista_de_lestras_de_la_palabra_a_encontrar)

lista_de_lestras_de_la_palabra_ingresada = list(palabra_ingresada)
print(lista_de_lestras_de_la_palabra_ingresada)
# Out:
# odontologo
# nitido
# ['o', 'd', 'o', 'n', 't', 'o', 'l', 'o', 'g', 'o']
# ['n', 'i', 't', 'i', 'd', 'o']

# %% [markdown]
# ## Challenge 5 🤺 - 25m
#
# `Pedir al usuario` que ingrese 1 palabra, luego `convertir` esa palabra a una `lista` con sus caracteres con `list()`. Agregar esa lista de caracteres a una lista llamada `palabras_ingresadas`. Repetir el proceso 3 veces. Cada vez que se agregue una lista de caracteres, imprimir la lista `palabras_ingresadas`.
#
#
# Ejemplo del resultado esperado:
#
# ```[['c', 'i', 'e', 'l', 'o']]``` # Al ingresar la primera palabra
#
# ```[['c', 'i', 'e', 'l', 'o'], ['c', 'a', 'l', 'o', 'r']]``` # Al ingresar la segunda palabra
#
# ```[['c', 'i', 'e', 'l', 'o'], ['c', 'a', 'l', 'o', 'r'], ['n', 'u', 'b', 'e', 's']]``` # Al ingresar la tercera palabra

# %%
# Mati
palabras1 = input('ingresar palabra')
palabra2 = input('ingresar 2da palabra')
palabra3 = input('ingresar 3ra palabra')
palabras_ingresadas = []


word1 = list(palabras1)
palabras_ingresadas.append(word1)
print(palabras_ingresadas)

word2 = list(palabra2)
palabras_ingresadas.append(word2)
print(palabras_ingresadas)

word3 = list(palabra3)
palabras_ingresadas.append(word3)
print(palabras_ingresadas)

# list(word1) list(word2) list(word3)
# Out:
# [['c', 'i', 'e', 'l', 'o']]
# [['c', 'i', 'e', 'l', 'o'], ['c', 'a', 'l', 'o', 'r']]
# [['c', 'i', 'e', 'l', 'o'], ['c', 'a', 'l', 'o', 'r'], ['n', 'u', 'b', 'e', 's']]

# %%
#carlos
lista_palabras = []
usuario = input('Ingrese la palabra')
palabras_ingresadas1 = list (usuario)
lista_palabras.append(palabras_ingresadas1)
print (lista_palabras)

usuario = input('Ingrese la palabra')
palabras_ingresadas2 = list (usuario)
lista_palabras.append(palabras_ingresadas2)
print (lista_palabras)

usuario = input('Ingrese la palabra')
palabras_ingresadas3 = list (usuario)
lista_palabras.append(palabras_ingresadas3)
print (lista_palabras)
# Out:
# [['c', 'i', 'e', 'l', 'o']]
# [['c', 'i', 'e', 'l', 'o'], ['c', 'a', 'l', 'o', 'r']]
# [['c', 'i', 'e', 'l', 'o'], ['c', 'a', 'l', 'o', 'r'], ['n', 'u', 'b', 'e', 's']]

# %%
palabras_ingresadas=[]
for i in range(3):
    palabras_ingresadas.append(list(input('ingrese una palabra ') ))
    print(palabras_ingresadas)
# Out:
# [['c', 'i', 'e', 'l', 'o']]
# [['c', 'i', 'e', 'l', 'o'], ['c', 'a', 'l', 'o', 'r']]
# [['c', 'i', 'e', 'l', 'o'], ['c', 'a', 'l', 'o', 'r'], ['n', 'u', 'b', 'e', 's']]

# %%
palabra_usuario_1 = input('Ingrese una palabra')
palabras_ingresadas = list(palabra_usuario_1)

print ([palabras_ingresadas])

palabra_usuario_2 = input('Ingrese otra palabra')
palabras_ingresadas_2 = list(palabra_usuario_2)

print([palabras_ingresadas, palabras_ingresadas_2])

palabra_usuario_3 = input('Ingrese otra palabra')
palabras_ingresadas_3 = list(palabra_usuario_3)

print([palabras_ingresadas,palabras_ingresadas_2,palabras_ingresadas_3])
# Out:
# [['c', 'i', 'e', 'l', 'o']]
# [['c', 'i', 'e', 'l', 'o'], ['c', 'a', 'l', 'o', 'r']]
# [['c', 'i', 'e', 'l', 'o'], ['c', 'a', 'l', 'o', 'r'], ['n', 'u', 'b', 'e', 's']]

# %%
lista_de_palabras = []
solicitar_palabra = input('ingrese resultado de la funcion: ')
codigo = list(solicitar_palabra)
lista_palabras.append(codigo)


print(codigo)

for i in range (2):
    print(codigo)
# Out:
# ['h', 'o', 'l', 'a']
# ['h', 'o', 'l', 'a']
# ['h', 'o', 'l', 'a']

# %% [markdown]
# Acercandonos un poco más a nuestro juego, vamos a ver cual es el proceso cada vez que se ingresa una palabra
#
# - Crear una lista vacía `letras_verificadas` para las letras de la palabra luego de ser verificada
# - Definir la cantidad de letras de la palabra a encontrar
# - Si las letras existen en la palabra a encontrar y sus posiciones coinciden: encerrar en corchetes `[]` y agregar al resultado
# - Si las letras existen en la palabra a encontrar pero sus posiciones no coinciden: encerrar en parentesis `()` y agregar al resultado
# - Si no se cumple ninguna de las anteriores, agregar la letra a la lista vacía sin modificaciones
# - Retornar el resultado

# %%
palabra_secreta = 'gatos'

def obtener_fila_verificada(palabra_a_encontrar, palabra_ingresada):
    cantidad_letras_de_palabra_a_encontrar = 5

    #creamos una lista vacia para almacenar el resultado
    letras_verificadas = []

    for posicion in range(cantidad_letras_de_palabra_a_encontrar): #5

        # es ogual el indice 0 de palabra_a_encontrar a indice 0 de palabra_ingresada?
        las_letras_son_iguales = palabra_a_encontrar[posicion] == palabra_ingresada[posicion]


        # la letra del indice 0 de palabra_ingresada en la palabra_a_encontrar
        la_letra_existe_en_la_palabra = palabra_ingresada[posicion] in palabra_a_encontrar

        if las_letras_son_iguales:
            # si se cumple guardamos en la lista de letras verificadas
            letras_verificadas.append('['+palabra_ingresada[posicion]+']')

        elif la_letra_existe_en_la_palabra:
            letras_verificadas.append('('+palabra_ingresada[posicion]+')')

        else:
            letras_verificadas.append(palabra_ingresada[posicion])

        
    return letras_verificadas

resultado = obtener_fila_verificada('perro', 'juego')
print(resultado)
# Out:
# ['j', 'u', '(e)', 'g', '[o]']

# %% [markdown]
# ## Challenge 6 🤺 - 25m
#
# Dada la lista de ejemplo:
#
# lista = [['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]
#
# `Crear una función` que `imprima` una grilla (lista de listas), `una línea` por cada lista dentro de la lista principal.
#
# Ejemplo del resultado esperado:
#
# ```
# ['h', 'o', 'l', 'i', 's']
# ['h', 'e', 'l', 'l', 'o']
# ['h', 'a', 'l', 'l', 'o']
# ```

# %%
# Lorena
lista = [['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]

def desglozar_lista(lista):
    for i in range (len(lista)):
        print(lista[i])

desglozar_lista (lista)
# Out:
# ['h', 'o', 'l', 'i', 's']
# ['h', 'e', 'l', 'l', 'o']

# %%
# Alejandro
def lista_imaginaria():
    lista_palabras = []

    palabra_num1=input('ingrese palabra')
  
    palabra_num2=input('ingrese otra')
    
    palabra_num3=input('ingrese la ultima')
    

    palabraN1= list(palabra_num1)
    lista_palabras.append(palabraN1)
    print(palabraN1)

    palabraN2= list(palabra_num2)
    lista_palabras.append(palabraN2)
    print(palabraN2)

    palabraN3= list(palabra_num3)
    lista_palabras.append(palabraN3)
    print(palabraN3)

    #2da forma 
    # def lista_imaginaria():
    # lista_imaginaria=['hola','util']

    # palabraN1= list(palabra_num1)
    # print(palabraN1)

    # palabraN2= list(palabra_num2)
    # print(palabraN1)

    # palabraN3= list(palabra_num3)
    # print(palabraN1)

lista_imaginaria()
# Out:
# ['h', 'o', 'l', 'a']
# ['q', 'u', 'e']
# ['t', 'a', 'l']

# %%
palabra_secreta = 'gatos'
intentos = 3

while intentos > 0:
    print(f'te quedan {intentos} intentos')
    palabra = input(' ingrese una palabra')

    # logica para verificar la palabra


    intentos = intentos - 1
    print(palabra)


print('ya no quedan intentos')
# Out:
# te quedan 3 intentos
# hola
# te quedan 2 intentos
# que
# te quedan 1 intentos
# tal
# ya no quedan intentos
